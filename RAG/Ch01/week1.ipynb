# %%
! pip install python-dotenv openAI langchain_core langchain_openai
# Out:
# Collecting python-dotenv
#   Obtaining dependency information for python-dotenv from https://files.pythonhosted.org/packages/0b/d7/1959b9648791274998a9c3526f6d0ec8fd2233e4d4acce81bbae76b44b2a/python_dotenv-1.2.2-py3-none-any.whl.metadata
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting openAI
#   Obtaining dependency information for openAI from https://files.pythonhosted.org/packages/c6/2e/3f73e8ca53718952222cacd0cf7eecc9db439d020f0c1fe7ae717e4e199a/openai-2.26.0-py3-none-any.whl.metadata
#   Downloading openai-2.26.0-py3-none-any.whl.metadata (29 kB)
# Collecting langchain_core
#   Obtaining dependency information for langchain_core from https://files.pythonhosted.org/packages/1f/d8/9418564ed4ab4f150668b25cf8c188266267d829362e9c9106946afa628b/langchain_core-1.2.18-py3-none-any.whl.metadata
#   Downloading langchain_core-1.2.18-py3-none-any.whl.metadata (4.4 kB)
# Collecting langchain_openai
#   Obtaining dependency information for langchain_openai from https://files.pythonhosted.org/packages/f0/0f/e4cb42848c25f65969adfb500a06dea1a541831604250fd0d8aa6e54fef5/langchain_openai-1.1.11-py3-none-any.whl.metadata
#   Downloading langchain_openai-1.1.11-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\rag\venv\lib\site-packages (from openAI) (4.12.1)
# Collecting distro<2,>=1.7.0 (from openAI)
#   Obtaining dependency information for distro<2,>=1.7.0 from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\rag\venv\lib\site-packages (from openAI) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openAI)
#   Obtaining dependency information for jiter<1,>=0.10.0 from https://files.pythonhosted.org/packages/cb/16/8e8203ce92f844dfcd3d9d6a5a7322c77077248dbb12da52d23193a839cd/jiter-0.13.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading jiter-0.13.0-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openAI)
#   Obtaining dependency information for pydantic<3,>=1.9.0 from https://files.pythonhosted.org/packages/5a/87/b70ad306ebb6f9b585f114d0ac2137d792b48be34d732d60e597c2f8465a/pydantic-2.12.5-py3-none-any.whl.metadata
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
#      ---------------------------------------- 0.0/90.6 kB ? eta -:--:--
#      ---------------------------------------- 90.6/90.6 kB 5.0 MB/s eta 0:00:00
# Collecting sniffio (from openAI)
#   Obtaining dependency information for sniffio from https://files.pythonhosted.org/packages/e9/44/75a9c9421471a6c4805dbf2356f7c181a29c1879239abab1ea2cc8f38b40/sniffio-1.3.1-py3-none-any.whl.metadata
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openAI)
#   Obtaining dependency information for tqdm>4 from https://files.pythonhosted.org/packages/16/e1/3079a9ff9b8e11b846c6ac5c8b5bfb7ff225eee721825310c91b3b50304f/tqdm-4.67.3-py3-none-any.whl.metadata
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ---------------------------------------- 57.7/57.7 kB ? eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\rag\venv\lib\site-packages (from openAI) (4.15.0)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain_core)
#   Obtaining dependency information for jsonpatch<2.0.0,>=1.33.0 from https://files.pythonhosted.org/packages/73/07/02e16ed01e04a374e644b575638ec7987ae846d25ad97bcc9945a3ee4b0e/jsonpatch-1.33-py2.py3-none-any.whl.metadata
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain_core)
#   Obtaining dependency information for langsmith<1.0.0,>=0.3.45 from https://files.pythonhosted.org/packages/d0/a8/4202ca65561213ec84ca3800b1d4e5d37a1441cddeec533367ecbca7f408/langsmith-0.7.16-py3-none-any.whl.metadata
#   Downloading langsmith-0.7.16-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in c:\rag\venv\lib\site-packages (from langchain_core) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\rag\venv\lib\site-packages (from langchain_core) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain_core)
#   Obtaining dependency information for tenacity!=8.4.0,<10.0.0,>=8.1.0 from https://files.pythonhosted.org/packages/d7/c1/eb8f9debc45d3b7918a32ab756658a0904732f75e555402972246b0b8e71/tenacity-9.1.4-py3-none-any.whl.metadata
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain_core)
#   Obtaining dependency information for uuid-utils<1.0,>=0.12.0 from https://files.pythonhosted.org/packages/83/92/2d7e90df8b1a69ec4cff33243ce02b7a62f926ef9e2f0eca5a026889cd73/uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata
#   Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain_openai)
#   Obtaining dependency information for tiktoken<1.0.0,>=0.7.0 from https://files.pythonhosted.org/packages/9d/15/963819345f1b1fb0809070a79e9dd96938d4ca41297367d471733e79c76c/tiktoken-0.12.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading tiktoken-0.12.0-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: idna>=2.8 in c:\rag\venv\lib\site-packages (from anyio<5,>=3.5.0->openAI) (3.11)
# Requirement already satisfied: certifi in c:\rag\venv\lib\site-packages (from httpx<1,>=0.23.0->openAI) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\rag\venv\lib\site-packages (from httpx<1,>=0.23.0->openAI) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\rag\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openAI) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\rag\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core) (3.0.0)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain_core)
#   Obtaining dependency information for orjson>=3.9.14 from https://files.pythonhosted.org/packages/af/9e/55c776dffda3f381e0f07d010a4f5f3902bf48eaba1bb7684d301acd4924/orjson-3.11.7-cp311-cp311-win_amd64.whl.metadata
#   Downloading orjson-3.11.7-cp311-cp311-win_amd64.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.1 kB ? eta -:--:--
#      ---------------------------------------- 43.1/43.1 kB 1.1 MB/s eta 0:00:00
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain_core)
#   Obtaining dependency information for requests-toolbelt>=1.0.0 from https://files.pythonhosted.org/packages/3f/51/d4db610ef29373b879047326cbf6fa98b6c1969d6f6dc423279de2b1be2c/requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\rag\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (2.32.5)
# Collecting xxhash>=3.0.0 (from langsmith<1.0.0,>=0.3.45->langchain_core)
#   Obtaining dependency information for xxhash>=3.0.0 from https://files.pythonhosted.org/packages/65/79/9d24d7f53819fe301b231044ea362ce64e86c74f6e8c8e51320de248b3e5/xxhash-3.6.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading xxhash-3.6.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain_core)
#   Obtaining dependency information for zstandard>=0.23.0 from https://files.pythonhosted.org/packages/43/a3/c6155f5c1cce691cb80dfd38627046e50af3ee9ddc5d0b45b9b063bfb8c9/zstandard-0.25.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openAI)
#   Obtaining dependency information for annotated-types>=0.6.0 from https://files.pythonhosted.org/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl.metadata
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=1.9.0->openAI)
#   Obtaining dependency information for pydantic-core==2.41.5 from https://files.pythonhosted.org/packages/11/66/f14d1d978ea94d1bc21fc98fcf570f9542fe55bfcc40269d4e1a21c19bf7/pydantic_core-2.41.5-cp311-cp311-win_amd64.whl.metadata
#   Downloading pydantic_core-2.41.5-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openAI)
#   Obtaining dependency information for typing-inspection>=0.4.2 from https://files.pythonhosted.org/packages/dc/9b/47798a6c91d8bdb567fe2698fe81e0c6b7cb7ef4d13da4114b41d239f65d/typing_inspection-0.4.2-py3-none-any.whl.metadata
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain_openai)
#   Obtaining dependency information for regex>=2022.1.18 from https://files.pythonhosted.org/packages/42/8b/1483de1c57024e89296cbcceb9cccb3f625d416ddb46e570be185c9b05a9/regex-2026.2.28-cp311-cp311-win_amd64.whl.metadata
#   Downloading regex-2026.2.28-cp311-cp311-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 41.5/41.5 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\rag\venv\lib\site-packages (from tqdm>4->openAI) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\rag\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\rag\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2.6.3)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading openai-2.26.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------------- -------------------------- 0.4/1.1 MB 8.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 0.8/1.1 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 9.0 MB/s eta 0:00:00
# Downloading langchain_core-1.2.18-py3-none-any.whl (503 kB)
#    ---------------------------------------- 0.0/503.0 kB ? eta -:--:--
#    ----------------------------- ---------- 368.6/503.0 kB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 503.0/503.0 kB 7.9 MB/s eta 0:00:00
# Downloading langchain_openai-1.1.11-py3-none-any.whl (87 kB)
#    ---------------------------------------- 0.0/87.7 kB ? eta -:--:--
#    ---------------------------------------- 87.7/87.7 kB ? eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.13.0-cp311-cp311-win_amd64.whl (204 kB)
#    ---------------------------------------- 0.0/204.6 kB ? eta -:--:--
#    --------------------------------------- 204.6/204.6 kB 12.1 MB/s eta 0:00:00
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.7.16-py3-none-any.whl (347 kB)
#    ---------------------------------------- 0.0/347.5 kB ? eta -:--:--
#    ------------------------------------- - 337.9/347.5 kB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 347.5/347.5 kB 7.2 MB/s eta 0:00:00
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
#    ---------------------------------------- 0.0/463.6 kB ? eta -:--:--
#    ------------------------------ --------- 358.4/463.6 kB 7.4 MB/s eta 0:00:01
#    ---------------------------------------- 463.6/463.6 kB 7.3 MB/s eta 0:00:00
# Downloading pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.0 MB 5.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.6/2.0 MB 6.2 MB/s eta 0:00:01
#    ------------------ --------------------- 0.9/2.0 MB 6.4 MB/s eta 0:00:01
#    --------------------------- ------------ 1.4/2.0 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.7/2.0 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 7.1 MB/s eta 0:00:00
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading tiktoken-0.12.0-cp311-cp311-win_amd64.whl (879 kB)
#    ---------------------------------------- 0.0/879.4 kB ? eta -:--:--
#    --------------- ----------------------- 358.4/879.4 kB 10.9 MB/s eta 0:00:01
#    --------------------------------------- 879.4/879.4 kB 11.1 MB/s eta 0:00:00
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.4 kB ? eta -:--:--
#    ---------------------------------------- 78.4/78.4 kB 4.3 MB/s eta 0:00:00
# Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
#    ---------------------------------------- 0.0/187.1 kB ? eta -:--:--
#    --------------------------------------- 187.1/187.1 kB 11.8 MB/s eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading orjson-3.11.7-cp311-cp311-win_amd64.whl (124 kB)
#    ---------------------------------------- 0.0/124.9 kB ? eta -:--:--
#    ---------------------------------------- 124.9/124.9 kB 7.6 MB/s eta 0:00:00
# Downloading regex-2026.2.28-cp311-cp311-win_amd64.whl (277 kB)
#    ---------------------------------------- 0.0/278.0 kB ? eta -:--:--
#    --------------------------------------- 278.0/278.0 kB 16.7 MB/s eta 0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#    ---------------------------------------- 54.5/54.5 kB ? eta 0:00:00
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading xxhash-3.6.0-cp311-cp311-win_amd64.whl (31 kB)
# Downloading zstandard-0.25.0-cp311-cp311-win_amd64.whl (506 kB)
#    ---------------------------------------- 0.0/506.2 kB ? eta -:--:--
#    --------------------------------------- 506.2/506.2 kB 16.0 MB/s eta 0:00:00
# Installing collected packages: zstandard, xxhash, uuid-utils, typing-inspection, tqdm, tenacity, sniffio, regex, python-dotenv, pydantic-core, orjson, jsonpatch, jiter, distro, annotated-types, tiktoken, requests-toolbelt, pydantic, openAI, langsmith, langchain_core, langchain_openai
# Successfully installed annotated-types-0.7.0 distro-1.9.0 jiter-0.13.0 jsonpatch-1.33 langchain_core-1.2.18 langchain_openai-1.1.11 langsmith-0.7.16 openAI-2.26.0 orjson-3.11.7 pydantic-2.12.5 pydantic-core-2.41.5 python-dotenv-1.2.2 regex-2026.2.28 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.4 tiktoken-0.12.0 tqdm-4.67.3 typing-inspection-0.4.2 uuid-utils-0.14.1 xxhash-3.6.0 zstandard-0.25.0
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
prompt = ChatPromptTemplate.from_template(
    "주제 {topic}에 대해 짧은 설명을 해주세요."
)

# %%
model = ChatOpenAI(model="gpt-5-nano")

# %%
output_parser = StrOutputParser()

# %%
chain = (
    {"topic" : RunnablePassthrough()}
    | prompt
    | model
    | output_parser
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 chain = (
#       2     {"topic" : RunnablePassthrough()}
#       3     | prompt
# ----> 4     | model
#       5     | output_parser
#       6 )
#
# NameError: name 'model' is not defined

# %%
chain.invoke("더블딥")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 chain.invoke("더블딥")
#
# NameError: name 'chain' is not defined
