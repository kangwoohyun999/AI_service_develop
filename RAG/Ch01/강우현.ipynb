# %%
# !pip install python-dotenv openAI langchain_core langchain_openai
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting openAI
#   Downloading openai-2.26.0-py3-none-any.whl.metadata (29 kB)
# Collecting langchain_core
#   Downloading langchain_core-1.2.18-py3-none-any.whl.metadata (4.4 kB)
# Collecting langchain_openai
#   Downloading langchain_openai-1.1.11-py3-none-any.whl.metadata (3.1 kB)
# Collecting anyio<5,>=3.5.0 (from openAI)
#   Downloading anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting distro<2,>=1.7.0 (from openAI)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openAI)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.10.0 (from openAI)
#   Downloading jiter-0.13.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openAI)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting sniffio (from openAI)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openAI)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting typing-extensions<5,>=4.11 (from openAI)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: idna>=2.8 in c:\python\lib\site-packages (from anyio<5,>=3.5.0->openAI) (3.11)
# Requirement already satisfied: certifi in c:\python\lib\site-packages (from httpx<1,>=0.23.0->openAI) (2025.11.12)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openAI)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openAI)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openAI)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=1.9.0->openAI)
#   Downloading pydantic_core-2.41.5-cp313-cp313-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openAI)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain_core)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain_core)
#   Downloading langsmith-0.7.16-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in c:\python\lib\site-packages (from langchain_core) (25.0)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain_core)
#   Downloading pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain_core)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain_core)
#   Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain_core)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain_core)
#   Downloading orjson-3.11.7-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain_core)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\python\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (2.32.5)
# Collecting xxhash>=3.0.0 (from langsmith<1.0.0,>=0.3.45->langchain_core)
#   Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain_core)
#   Downloading zstandard-0.25.0-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain_openai)
#   Downloading tiktoken-0.12.0-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain_openai)
#   Downloading regex-2026.2.28-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\python\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\python\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2.6.0)
# Collecting colorama (from tqdm>4->openAI)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading openai-2.26.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 14.3 MB/s  0:00:00
# Downloading anyio-4.12.1-py3-none-any.whl (113 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jiter-0.13.0-cp313-cp313-win_amd64.whl (202 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 22.7 MB/s  0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading langchain_core-1.2.18-py3-none-any.whl (503 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langsmith-0.7.16-py3-none-any.whl (347 kB)
# Downloading pyyaml-6.0.3-cp313-cp313-win_amd64.whl (154 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
# Downloading langchain_openai-1.1.11-py3-none-any.whl (87 kB)
# Downloading tiktoken-0.12.0-cp313-cp313-win_amd64.whl (879 kB)
#    ---------------------------------------- 0.0/879.1 kB ? eta -:--:--
#    ---------------------------------------- 879.1/879.1 kB 23.8 MB/s  0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading orjson-3.11.7-cp313-cp313-win_amd64.whl (124 kB)
# Downloading regex-2026.2.28-cp313-cp313-win_amd64.whl (277 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading xxhash-3.6.0-cp313-cp313-win_amd64.whl (31 kB)
# Downloading zstandard-0.25.0-cp313-cp313-win_amd64.whl (506 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, typing-extensions, tenacity, sniffio, regex, pyyaml, python-dotenv, orjson, jsonpointer, jiter, h11, distro, colorama, anyio, annotated-types, typing-inspection, tqdm, tiktoken, requests-toolbelt, pydantic-core, jsonpatch, httpcore, pydantic, httpx, openAI, langsmith, langchain_core, langchain_openai
#
#    ---- -----------------------------------  3/30 [typing-extensions]
#    -------- -------------------------------  6/30 [regex]
#    ---------- -----------------------------  8/30 [python-dotenv]
#    ---------------- ----------------------- 12/30 [h11]
#    -------------------- ------------------- 15/30 [anyio]
#    -------------------- ------------------- 15/30 [anyio]
#    ------------------------ --------------- 18/30 [tqdm]
#    -------------------------- ------------- 20/30 [requests-toolbelt]
#    ---------------------------- ----------- 21/30 [pydantic-core]
#    ------------------------------ --------- 23/30 [httpcore]
#    -------------------------------- ------- 24/30 [pydantic]
#    -------------------------------- ------- 24/30 [pydantic]
#    -------------------------------- ------- 24/30 [pydantic]
#    --------------------------------- ------ 25/30 [httpx]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ---------------------------------- ----- 26/30 [openAI]
#    ------------------------------------ --- 27/30 [langsmith]
#    ------------------------------------ --- 27/30 [langsmith]
#    ------------------------------------ --- 27/30 [langsmith]
#    ------------------------------------- -- 28/30 [langchain_core]
#    ------------------------------------- -- 28/30 [langchain_core]
#    ------------------------------------- -- 28/30 [langchain_core]
#    ------------------------------------- -- 28/30 [langchain_core]
#    ------------------------------------- -- 28/30 [langchain_core]
#    ---------------------------------------- 30/30 [langchain_openai]
#
# Successfully installed annotated-types-0.7.0 anyio-4.12.1 colorama-0.4.6 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 jiter-0.13.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain_core-1.2.18 langchain_openai-1.1.11 langsmith-0.7.16 openAI-2.26.0 orjson-3.11.7 pydantic-2.12.5 pydantic-core-2.41.5 python-dotenv-1.2.2 pyyaml-6.0.3 regex-2026.2.28 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.4 tiktoken-0.12.0 tqdm-4.67.3 typing-extensions-4.15.0 typing-inspection-0.4.2 uuid-utils-0.14.1 xxhash-3.6.0 zstandard-0.25.0
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\python\python.exe -m pip install --upgrade pip

# %%
from langchain_openai import ChatOpenAI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from langchain_openai import ChatOpenAI
#
# ModuleNotFoundError: No module named 'langchain_openai'
